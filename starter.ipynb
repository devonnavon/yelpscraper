# %%
import requests
import certifi
from bs4 import BeautifulSoup
import ast

# %%
certifi.where()
# Out:
# '/anaconda3/lib/python3.6/site-packages/certifi/cacert.pem'

# %%
#Headers will make it look like you are using a web browser
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.90 Safari/537.36'}

http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())

certifi.where()

reviews = []

for i in range(0,500,20):
    url = 'https://www.yelp.com/biz/shangri-la-austin-2?start={}&sort_by=date_desc'.format(i)
    response = requests.get(url, headers=headers, verify=False).text
    page = BeautifulSoup(response, "lxml")
    #on the first request we get business data
    if i == 0: 
        header = page.find('div',attrs={'class': 'content-container js-biz-details'})
        name = header.find_all('h1',attrs={'class': 'biz-page-title embossed-text-white shortenough'})[1].text
        price = header.find('span',attrs={'class':'business-attribute price-range'}).text
        ratings = ast.literal_eval(header.find('div', attrs={'id':"rating-details-modal-content"}).attrs['data-monthly-ratings'])
        hours = [dict([x.text.strip().split('\n\n')[0:2]]) for x in page.find('table',attrs={'class':'table table-simple hours-table'}).find_all('tr')]
        info_raw = page.find('div',attrs={'class':'short-def-list'})
        info = dict(zip([x.text.strip() for x in info.find_all('dt')], [x.text.strip() for x in info.find_all('dd')]))
    else: pass
    for p in page.find_all("div", attrs={'class': 'review-content'}):
        date = p.find('span', attrs={'class': 'rating-qualifier'}).text.strip()
        rating = float(p.find('img').attrs['alt'][:3])
        content = p.find('p', attrs={'lang': 'en'}).text
        review = {
            'date' : date,
            'rating' : rating,
            'content' : content
        }
        reviews.append(review)

scrape = {
    'name':name,
    'price':price,
    'ratings':ratings,
    'hours':hours,
    'info':info,
    'reviews':reviews
}
# Out:
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
scrape
# Out:
# {'name': 'Shangri-La',
#  'price': '$',
#  'ratings': {'2016': [[0, 3.5],
#    [1, 4.0],
#    [2, 3.5],
#    [3, 3.5],
#    [4, 3.5],
#    [5, 3.5],
#    [6, 3.0],
#    [7, 3.5],
#    [8, 3.5],
#    [9, 3.5],
#    [10, 3.5],
#    [11, 3.5]],
#   '2017': [[0, 3.5],
#    [1, 3.5],
#    [2, 3.5],
#    [3, 3.5],
#    [4, 3.5],
#    [5, 3.5],
#    [6, 3.5],
#    [7, 3.0],
#    [8, 3.0],
#    [9, 3.0],
#    [10, 3.0],
#    [11, 3.5]],
#   '2018': [[0, 3.5],
#    [1, 3.5],
#    [2, 3.5],
#    [3, 4.0],
#    [4, 4.5],
#    [5, 4.5],
#    [6, 4.5],
#    [7, 4.0],
#    [8, 4.0],
#    [9, 3.5],
#    [10, 3.0],
#    [11, 3.0]],
#   '2019': [[0, 3.0],
#    [1, 3.5],
#    [2, 3.0],
#    [3, 3.0],
#    [4, 3.5],
#    [5, 4.0],
#    [6, 4.0],
#    [7, 4.0]],
#   '2015': [[0, 3.5],
#    [1, 3.5],
#    [2, 4.0],
#    [3, 4.5],
#    [4, 4.5],
#    [5, 4.5],
#    [6, 3.5],
#    [7, 3.5],
#    [8, 3.5],
#    [9, 3.5],
#    [10, 3.5],
#    [11, 3.5]]},
#  'hours': [{'Mon': '4:00 pm - 2:00 am'},
#   {'Tue': '4:00 pm - 2:00 am'},
#   {'Wed': '4:00 pm - 2:00 am'},
#   {'Thu': '4:00 pm - 2:00 am'},
#   {'Fri': '2:00 pm - 2:00 am'},
#   {'Sat': '2:00 pm - 2:00 am'},
#   {'Sun': '2:00 pm - 2:00 am'}],
#  'info': {'Takes Reservations': 'No',
#   'Accepts Credit Cards': 'Yes',
#   'Accepts Apple Pay': 'No',
#   'Parking': 'Street',
#   'Bike Parking': 'Yes',
#   'Good for Groups': 'Yes',
#   'Ambience': 'Divey, Hipster',
#   'Noise Level': 'Loud',
#   'Music': 'Live, Juke Box',
#   'Alcohol': 'Full Bar',
#   'Good For Happy Hour': 'Yes',
#   'Best Nights': 'Thu, Fri, Sat',
#   'Smoking': 'Outdoor Area / Patio Only',
#   'Outdoor Seating': 'Yes',
#   'Wi-Fi': 'No',
#   'Has TV': 'Yes',
#   'Dogs Allowed': 'Yes',
#   'Has Pool Table': 'Yes'},
#  'reviews': [{'date': '7/30/2019',
#    'rating': 5.0,
#    'content': "We have been to Shangri-la a couple of times now, and I can't really pinpoint what I like about this place, but I know I like to go there and meet with friends to sit in the backyard.The prices are fair, the people are great and there's a pool.Although there's five similar bars to this in the 500 feet radius, this is definitely a great one.Definitely try the Miami Vice frozen drink on a hot (Summer)day.I would say come for the live music, but that is one of the only things I have never seen here"},
#   {'date': '7/27/2019',
#    'rating': 1.0,
#    'content': 'I was the only Latino in the group and got kicked by a white man who also told me to "suck a lot of dicks." Tried talking to the other white manager, he told me that my "could stay, but you can leave." Austin in disguise man. Racism in disguise I guess. Also, he yelled at our table because he said we were in his way and when we moved for this princess, he came to our table and targeted me. Hate to throw out there again, but I was the only Latino in the table. Whatever I guess, racism is okay to these peeps.'},
#   {'date': '7/27/2019',
#    'rating': 2.0,
#    'content': "Atmosphere has potential, but service killlllllls it! We came on a Friday night, excited to try a new place with my boyfriend. Walking into a building that continues into a private courtyard-like setting was super cool. BUT the vibe was totally shot when the bartender called my boyfriend out for waiting at the counter with his debit card. (My boyfriend works in the liquor industry for 5+ years and has never had this experience). The bartender singled him out in front of everyone standing there and was completely disrespectful. Were willing to give this place one more try (only because they're dog friendly and the patio was cool). But don't expect polite service."},
#   {'date': '7/25/2019',
#    'rating': 5.0,
#    'content': 'One of my favorite Austin bars. Cool environment, they have 2 pool tables, a photo booth, and a large bad*ss porch. I enjoy going both alone or with a group of friends. Staff is very friendly and quick to help. Also, the food truck in the back is amazing, try it!!'},
#   {'date': '6/25/2019',
#    'rating': 5.0,
#    'content': 'Love this place. Great vibes. Emily, Benton, and Gus are fantastic bartenders and the rest of the staff is so friendly. Ready for a chill night and good drinks on the patio!!'},
#   {'date': '6/7/2019',
#    'rating': 4.0,
#    'content': "I can't really pinpoint my finger on what I like or dislike about Shangri-La, and I've been here 5 or 6 times in the month or two that I've lived in Austin. I'd say it's your average East 6th bar, and I don't love it, but we do end up here on a typcial weekend. Haven't tried the food truck in the back but I'd say the outside patio is the most social environment on the block. To me, it's a solid 3.5* bar choice, and I'll round up to 4* since I keep going back. Just can't get convinced that it's actually worth a full 4 stars, but maybe time will change my opinion."},
#   {'date': '5/2/2019',
#    'rating': 5.0,
#    'content': 'Outstanding outside patio. \xa0Undoubtedly the best painkillers in Austin. \xa0I believe this was the first bar east of 35 on 6th.'},
#   {'date': '4/28/2019',
#    'rating': 4.0,
#    'content': "This seems to be a local favorite and I'm glad I saw it. I went for a night cap here after another event with a group and the patio tables were perfect. I liked the easy vibe and food truck for evening snacks of hush puppies and beignets."},
#   {'date': '4/14/2019',
#    'rating': 3.0,
#    'content': 'Stopped in during girls weekend for my birthday. Like other reviews said, terrible service. Since they didnt have much on the menu, I asked for a sweeter drink since it was my birthday. Her reply was "pretty limited there". Based on reviews I wouldn\'t think so. She made me an Old Fashioned. I know when you dont know what to order is the most annoying for a bartender, but having never been there I had no clue on availability. Wont go back.'},
#   {'date': '4/7/2019',
#    'rating': 5.0,
#    'content': 'I have searched literally everywhere for a piña-colada in Austin and I finally found one. If you need to feel like you are on vacation on a Sunday day afternoon this is the place to be!'},
#   {'date': '3/18/2019',
#    'rating': 3.0,
#    'content': "Not to be confused with Sangria Lay which is when you get drunk with a Spanish girl or boy and end up having sex.I didn't know cigarettes were such a big deal in the modern day and age. And vaping as well. I'm talking about such a massssssssive deal. The entire place is just one big cloud of smoke. The guy on the front door was nice enough and there were some superrrr sexy people here and lots of trendy and young people here, so many, but really, seriously. That smoke. Could not hang out here."},
#   {'date': '3/16/2019',
#    'rating': 4.0,
#    'content': 'This is an Austin classic that calls back to East 6th a decade ago. The patio is large and more recently redone.'},
#   {'date': '2/17/2019',
#    'rating': 5.0,
#    'content': "After living in Austin coming back for a friend's wedding. Came in to the bar for old times sake. It's good to know it's still here from what looks like a gutting of East 6th into an upper class urban dream. Drinks are cheap and stiff and the bar staff hustles hard. Unfortunately the guy who made the burgers in a box is long gone but food is still on site."},
#   {'date': '11/17/2018',
#    'rating': 1.0,
#    'content': "It is my birthday and the bouncer was so rude and almost wouldn't let me in. He judged me and didn't believe I had 2 drinks. He ruined my evening with being rude and inconsiderate. Then justifying at the end of his argument that this was his second day and he didn't know what he was doing. I will never go back and do not recommend this establishment to anyone."},
#   {'date': '10/27/2018',
#    'rating': 1.0,
#    'content': "Worst place I've ever been too. \xa0Bartenders were rude, the girl had a terrible attitude. Was calling us racist for being dressed as Native Americans. The other bartender then threw out the drinks and kicked us out.Let me just state something before everyone calls out their opinion of costumes. Had a manager come to me privately and told me they felt our costumes were insensitive I might have understood, however to be openly called a racist based on the way we looked seems kind of ironic."},
#   {'date': '8/11/2018',
#    'rating': 2.0,
#    'content': "I don't care how cheap the drinks are, or how hip the crowd is. Walking out to the patio, the overwhelming smell of 3 day old vomit that has baked in the 90 degree weather, is inexcusable. If that is considered charm, then I wish them well as I will never return.There are far better dives on the Eastside, and in Austin in general."},
#   {'date': '8/9/2018',
#    'rating': 1.0,
#    'content': 'If I had the option to give no stars, I would have... This past weekend I visited Austin on a friend trip. Friday night we came to meet people at Shangri-la. It was to my surprise that upon getting out of the uber and giggling with our driver we were told by the door guy that we were having too much fun to go inside and he turned us away, suggesting we walk down to Liberty. When we asked if one of us could go inside and let the people we were there to meet know that we could not stay, the door guy declined and advised us to just text them. My boyfriend then turned his hat backward, got in line, and was allowed inside. So apparently this guy was not the brightest but just on a power high. I would like to thank this door guy for directing about 12 people to another bar to spend their money. Also, after reading other reviews I have noticed that turning people away for no reason is a trend.'},
#   {'date': '7/22/2018',
#    'rating': 5.0,
#    'content': "Was visiting for a conference and multiple people told us to come here at night! There's a pool table and darts in the bar and a cute little patio area in the back. There's a creole food truck as well. People bring their dogs here which is awesome and everyone is super friendly! I would say it's a very quintessential Austin bar. Drinks are fun and cheap - highly recommend for a low key, chill night."},
#   {'date': '7/22/2018',
#    'rating': 4.0,
#    'content': "Pretty easy going relaxing place. Love that people can bring their dogs and sit outside. Lines weren't too bad for Saturday night. Cider was a little more bitter than I like but good overall. We sat outside which was great. Had an amazing time."},
#   {'date': '5/20/2018',
#    'rating': 5.0,
#    'content': 'A dive bar that stands out due to how surprisingly friendly its staff is, which makes it a bit of a throwback for the downtown bar scene.'},
#   {'date': '4/24/2018',
#    'rating': 5.0,
#    'content': 'Cool place. People bring their dogs and you can pet them. One dog was missing an eye. It was kinda gross but he was nice. The ambiance is pretty nice.'},
#   {'date': '4/15/2018',
#    'rating': 5.0,
#    'content': 'Awesome patio. Cheap beer and drinks. Great jukebox. Friendly staff. Old Austin. What more could you ask for?!'},
#   {'date': '3/17/2018',
#    'rating': 1.0,
#    'content': 'Extremely rude bartender threw away my fiancé\'s beer because he was on his phone at the bar. He was alone AND on the phone with his brother. He told the bartender, "Hey! Don\'t be rude, I come here all the time" and she said, "I do too sweetie, try your luck somewhere else." NOPE.'},
#   {'date': '2/17/2018',
#    'rating': 5.0,
#    'content': 'Great prices. Solid drinks. Pool & photo booth. Never a long wait. Always a seat outside. My favorite bar in Austin.'},
#   {'date': '12/31/2017',
#    'rating': 5.0,
#    'content': 'Great atmosphere. Really enjoyed the intimate setting. Good for groups to chat and relax.'},
#   {'date': '12/31/2017',
#    'rating': 4.0,
#    'content': 'Food is very good. Large \xa0selection .Price are ok. Delivery is pretty fast. Nice workers.i would recommend this place to anyone.'},
#   {'date': '12/22/2017',
#    'rating': 5.0,
#    'content': 'I arrived 4pm 12-22-17.To the Best Person.Emily. Not sure if spelt correctly.But She was Interactive. It seemed effortless to Her... Emily was Incredible!People started arriving... still on Her Game!I Will Always Wish Great People Well.Thank You,DarrinShe Was the Bartender.'},
#   {'date': '12/20/2017',
#    'rating': 3.0,
#    'content': 'This was the divey-est bar we went to while in Texas. Its dark, dingy, and filled with regulars drinking lone star. The drinks were cheap and they had two pool tables so I was a happy camper. The hiptser bar tender acted pissy towards us when we asking a few questions while trying to figure out what we wanted to drink. I dont know if he was in a bad mood or just an ass, but it was kind of annoying. Barring that, Shangri-La was a good stop for cheap drinks and pool. Plus one star for them having Its Always Sunny playing on the TVs.'},
#   {'date': '11/5/2017',
#    'rating': 5.0,
#    'content': "Didn't spend much time inside but the patio was fantastic. Lots of seating and there was a separate bar out there as well as a food cart. Pretty casual atmosphere and would definitely come back here to hang out!"},
#   {'date': '10/4/2017',
#    'rating': 4.0,
#    'content': 'Great vibe even at 12 am on a Tue night. The hidden back garden is uber cool! Had the salad to satisfy midnight hunger cravings and it did not disappoint. Check it out!'},
#   {'date': '8/25/2017',
#    'rating': 1.0,
#    'content': "This used to be a chill bar to hang out at. \xa0I don't know what happened but they last two times I have attempted to enter I haven't been allowed in. \xa0Whomever they have at the door is very rude. \xa0The last denial was on St. Patrick's day, which also happens to fall during SXSW. \xa0We were on the East side listening to music. \xa0We went to see some live music that was playing here and we were denied entrance because we were wearing green. \xa0I am sure they will be happy I will not be returning as they don't seem to want me there to begin with."},
#   {'date': '8/11/2017',
#    'rating': 1.0,
#    'content': "If there was an option to not give a start I would have selected that. The bartender was a complete ass. I had an unopened bottle of water and he said I had to through it away. I went to eat at the food truck and since my friend did not have their ID he would not let us. Needless to say I won't ever step foot in there again."},
#   {'date': '8/7/2017',
#    'rating': 1.0,
#    'content': "Whoever the guy is at the bar at 6pm Tuesday's ...completely and unnecessarily rude. Will not be returning"},
#   {'date': '7/29/2017',
#    'rating': 4.0,
#    'content': "Would have been a an easy 5 if the jukebox wasn't crap and the half the bar filled with bros. \xa0 \xa0Great bartenders and atmosphere. \xa0The other half of the bar filled with is tattooed sub/counter culture types made me feel right at home. We went on a Thursday. \xa0No idea what this place is like on a weekend. \xa0Might be totally different but I would try it."},
#   {'date': '7/7/2017',
#    'rating': 5.0,
#    'content': 'Delightful Spot To Find Yourself @ 2AM For Early Morning ShenanigansSITREPOn a Monday night - or really, early early Tuesday morning - I can not think of a more fun spot to be drinking tasty cocktails and playing Cards Against Humanity.yelp.com/biz_photos/shan…THE SETUPThe locals, such as my lovely friend Luci H., call it "Shang", because it is indeed a "S(weet)hang(out)". \xa0 I also think of the word "Shenanigans", because "Shang" could be an abbreviation for that too. ;)But in fact, I can\'t think of a more perfect quiet chill-spot to just converse and play games. \xa0When I was here, we were all immersed in the quiet enjoyment of each other\'s contemplations and laughter - which tends to happen quite a bit with Cards Against Humanity.MUNCHIESThe embedded food truck Baton Creole provides some pretty tasty bites with a spicy seafood flare, including tacos and crab cakes.THE DRINKSTasty cocktails abound here, such as the Tangri-la, a mesmerizing citrusy masterpiece that had our tastebuds jumping so loudly we could barely hear ourselves think.yelp.com/biz_photos/shan…THE LOWDOWNCome for the drinks, stay for the absolute naughtiness of Cards Against Humanity and perverse friends! \xa0"You have won me over, Shang".'},
#   {'date': '5/11/2017',
#    'rating': 4.0,
#    'content': "Tiki dive bar! This place is a cool place to hang out on the back patio. They've got a nice place in the shade with a stage and a fair amount of seating to check out the acts that they play. Having a tiki bar with frozen drinks and cold beers makes it a great place to chill to some good tunes. Inside it's pretty dingy- a dark bar with a cool retro vibe. The large chandelier hanging in the center of the dance floor makes the place look a bit more formal! They offer cheap beer- go for the Lone Star tallboys IMHO for the best bang for your buck here. They do a great job on SXSW here, teaming up with Boulevard Beer and some music coalition that seems to support Midwestern music- they jam it out here, and have great beer with the best new artists you've probably never heard of. The bathrooms are nothing pretty- but they put portapotties outside during the busiest times of the year."},
#   {'date': '5/7/2017',
#    'rating': 4.0,
#    'content': "It's all about $2 Tuesdays. Just a good old fashioned dive bar with surprisingly a lot of space that has a certain coziness to it. If you're looking to spend less than 15 bucks this is the place, with their 16oz domestic cans and well drinks for $2 all night."},
#   {'date': '3/27/2017',
#    'rating': 1.0,
#    'content': 'Went on Saturday with three girlfriends and had a good time. We left to go check out another place for about an hour and decided to come back. We walked back to Shang with two black gentleman and were denied in. We were perfectly fine. Actually one of the girls didn\'t even drink so.. The front door guy said "no I think you\'re fine" fine? "Yeah" what do you mean by that? Are we being denied? "Yeah" why? "You\'re fine" or \xa0door guy was it you felt threatened by the amazingly sweet gentleman we came with?!? ... being a born and raised Austinite, I can definitely say this is the shit Austin has become. I\'ll keep my business south where all are welcome and old Austin still lives.'},
#   {'date': '1/26/2017',
#    'rating': 5.0,
#    'content': "If you wanna get sloshed on a budget then this is your place!! My favorite bar cuz those prices are so damn good and the bartenders are extra sweet. Plus lots of seating! Kemuri staff loves y'all!!"},
#   {'date': '12/7/2016',
#    'rating': 5.0,
#    'content': "This was the best bar we went to in Austin. \xa0I love a good dive. \xa0This is in my top three of all time. \xa0The bartender was great. \xa0Not just PBR, LoneStar, and crap beer here. \xa0I had a delicious craft cocktail, two local craft beers, a couple Wellars, and pumped about $20 in the Juke box. \xa0Wouldn't have left all night, but got a text with horrible news. \xa0This place was excellent!!!"},
#   {'date': '12/1/2016',
#    'rating': 4.0,
#    'content': 'We came in here around December/January of last year and it was a chilled out spot. Sadly I have not been back in a minute and I really enjoyed it. Hope to go by again...just hard to find parking in this area. We ordered an old-fashioned and it was pretty good, a little strong, not as much finesse as other places but it was decent. ok music.'},
#   {'date': '11/5/2016',
#    'rating': 4.0,
#    'content': "Dive-bar at its best. Austin is known to be a hipster place and this place hit the spot. Don't expect modern upscale NY bar here... this place is like a hole in the wall and offers pool table, photo booth, and awesome selection. I love the Deep Eddy drinks they have and the rest of the cocktails look great. Very comfortable vibe and the bartenders are knowledgeableI would come again if I ever visit Austin again. And I hope this place is still around when I do."},
#   {'date': '11/1/2016',
#    'rating': 1.0,
#    'content': 'Absolutely horrendous. I am a local, but my friend was turned away because she had a Wisconsin ID. no other reason. My friend and I would have pumped a good $100 into their business. We were not drunk or belligerent. I should have recorded the interaction because it is so unbelievable. Some "bouncer" at the door said "I am legally allowed to deny service for any reason" and told us to leave.This business model is absolutely appalling and that bouncer needs to be fired immediately.'},
#   {'date': '10/20/2016',
#    'rating': 3.0,
#    'content': "Absolutely the most dated bar on the east side in terms of being cool for not giving a flying fuck about anything. \xa0Shangri la keeps intact its roots of bartenders concerned with their locals' and patsies. I'd go four star cause it's fun but it's so stupid austin cliche that it's lucky to have 3. Still though. It deserves all 3."},
#   {'date': '8/22/2016',
#    'rating': 4.0,
#    'content': 'Chill bar. Pool tables, photo booth, very spacious which was nice.Settled down for a few drinks. Ritual lone star and my two friends had their usual whiskey and soda. Samples a few of the signature frozen drinks and enjoyed those a lot. The "Shangri-La" and the "Dmango Unchained." Also had a "Southern Peach" which was decent but the frozen drinks certainly shine.'},
#   {'date': '7/10/2016',
#    'rating': 2.0,
#    'content': "Dead atmosphere, drab lighting; just another dive bar. \xa0Chairs were pleasantly squishy, though.Definitely one of those places with arbitrary and invisible pricing of beverages that will increase and decrease drastically based on how cool they perceive you to be. \xa0So try not to piss off the dour Chandler-Bing-doppleganger of a bartender.Otherwise you'll likely find yourself paying more than your friend for a crummy cocktail, like I did.Painkiller, my arse."},
#   {'date': '7/2/2016',
#    'rating': 4.0,
#    'content': "Shangri-La? More like Hangri-La. Shang is the perfect place for a friend-hang. The divey, quirky atmosphere is perfect for a group of friends in the early evening. Long tables, outdoor bar, quick service. What more could you want in a East 6th Bar? They even have Porta-potties for the adventurous. Not only is it a great spot for groups, it's also a great nighttime joint, too. It should be part of everyone's stop-in list when doing an East 6th bar hop."},
#   {'date': '5/29/2016',
#    'rating': 4.0,
#    'content': 'Very fun outdoor area with a lot of string lights which are nice. They also had tasty drinks. Win overall! My friend ordered a blended mango drink which was really tasty, and I got a cider.'},
#   {'date': '5/15/2016',
#    'rating': 5.0,
#    'content': 'great divish bar. \xa0cool place to escape the general madness of 6th street. \xa0head east until you reach Shangri-la.'},
#   {'date': '5/12/2016',
#    'rating': 5.0,
#    'content': "LOVE this bar. My new favorite in Austin. Drinks are insanely cheap, there's a Photobooth, a juke box, a great patio. What more could you want?"},
#   {'date': '5/9/2016',
#    'rating': 4.0,
#    'content': "Cute bar. Didn't check out the back/outside, as there was a wedding reception and it was loud and crowded. But inside was nice. Bartender was a sweetheart and made some great drinks (frozen Irish coffee was the bomb). Cheap prices, 2 pool tables, jukebox, a photo booth and an arcade machine. Only downside to this bar was just 1 bathroom per gender (only one stall, so ladies end up having to wait a few minutes sometimes). Otherwise a very cool place."},
#   {'date': '3/20/2016',
#    'rating': 4.0,
#    'content': 'Saw a band perform here for SXSW and it was fun. Bar has a cool divey feel to it. 16 oz Lone Star was $5, I suppose for South by "surge pricing" it was that, I hope it\'s cheaper otherwise. Overall a chill spot.'},
#   {'date': '3/19/2016',
#    'rating': 1.0,
#    'content': "Bad experience. The bartenders were very rude. They wouldn't serve me. Maybe it's because of my strong southern draw, but it was ridiculous."},
#   {'date': '3/17/2016',
#    'rating': 1.0,
#    'content': 'During sxsw my friends and I attempted to check out this place and not only were we rejected but we were yelled at for wearing green on St. Patrick\'s day. I fully respect a businesses choice to refuse business to anyone but for wearing green on the only day of the year where everyone wears green? It felt petty and ridiculous. Not only did we get turned away, we got an earful from the supposed "door guy". I\'ll spend my "green" money somewhere else from now on.'},
#   {'date': '3/17/2016',
#    'rating': 1.0,
#    'content': "Wow...we just got turned away on St. Paddy's day because we're wearing green. It's Austin for goodness sake. \xa0I'm sure my green money will work just as well anywhere else."},
#   {'date': '3/15/2016',
#    'rating': 5.0,
#    'content': 'Awesome patio, reasonably priced drinks, fantastic staff! \xa0Steve was super helpful and gave us some great recommendations.'},
#   {'date': '3/4/2016',
#    'rating': 5.0,
#    'content': 'Had a drink called a fancy Jeeves blew my god dayum mind! Clutch door guy named brad told me to check out some dope dank dank metal bands. Had a bartender named Trevor or some shit. dude had a sick beard. He told me about his new camper. Gotta love that Austin lifestyle keep it wiggidy weird. Dope ass pool tables like woah! Had some killer Chex mix bro to finish off the night.'},
#   {'date': '2/16/2016',
#    'rating': 5.0,
#    'content': "Have wanted to stop here for awhile and finally went in with a friend for a drink before an art event. \xa0We enjoyed this dive with it's cool bar. \xa0Outside patio looked nice. \xa0It was cold so we stayed inside. \xa0Best thing besides the tasty drink was the very nice and friendly bartender. \xa0Not sure of his name (Jordan, maybe?). \xa0So--manager/owner note it was whoever was working 5:00 on Sat. 2/6. \xa0He told us about the event the next day as well as other happenings. \xa0Could not come back that Sunday, but will be back soon."},
#   {'date': '1/15/2016',
#    'rating': 5.0,
#    'content': "Oh Shangri-La ... you are one of my favorites for sure! \xa0You really are a perfect bar in every way. \xa0I love your location ... it's a quick getaway from dirty 6th. \xa0Your bartenders are awesome and always make a good drink. \xa0I love the new addition of the frozen drinks. \xa0As a girl with fancy tastes I am totally into that! \xa0You also have one of the best patios in all of Austin. \xa0Plenty of tables and trees about to keep you shaded. \xa0You also throw the best parties! \xa0Remember the Halloween pumpkin smashing thing - a total blast! \xa0I always end up at your sxsw parties too! \xa0So in conclusion y'all got a good thing going here and I will continue to partake in your booze and activities! \xa0Thanks for being great!"},
#   {'date': '12/13/2015',
#    'rating': 5.0,
#    'content': "Still love this bar after all these years. The patio is like a big party out at someone's house but with better drinks. BEDFORD is the best door guy I've ever encountered."},
#   {'date': '12/4/2015',
#    'rating': 5.0,
#    'content': "Shangri-La is one of the best bars on the east side hands down. They have a really amazing outdoor sitting area. On a Friday or Saturday night, you'll never find that place empty. They used to have an East Side King in the back, but that location closed awhile ago. However, if you walk across the street to Waller and 6th st, there is a food truck mecca. The bartenders are always attentive and incredibly nice. This is a great place to grab a drink with friends and chill."},
#   {'date': '10/26/2015',
#    'rating': 5.0,
#    'content': 'Great beer, great atmosphere, fun employees, overall, a great experience. I went there on my last visit to Austin with my mates. I had Eastciders all night, and great conversations with a bartender about the Golden Girls! Loved it!'},
#   {'date': '9/11/2015',
#    'rating': 5.0,
#    'content': 'This is the "go to" spot amongst my friends and I. Their outdoor patio is humongous, and inside has several tables and seating options. There\'s two pool tables, and I love all the guys that work here. They\'re all super friendly and do their jobs well. It\'s just a chill, comfortable spot to be at. Drinks are a fair price, and while I can\'t deny it\'s becoming more and more popular and known (do I say mainstream?) to the newcomers of Austin, I still love coming out to Shangs any night of the week.'},
#   {'date': '9/9/2015',
#    'rating': 1.0,
#    'content': 'Bartenders are slow and snobbish, if they deign to recognize you at all. Seriously, even by Austin standards, these bartenders are hipster douchebags.'},
#   {'date': '9/6/2015',
#    'rating': 1.0,
#    'content': "I'm never coming back to this place and neither should you. The bar was pretty full, but I was able to get a spot at the bar to order a drink for myself and my friend. They were pretty busy, so I patiently waited. After some eye contact with the bartender, I assumed I was next, but that never happened. I would make eye contact with the bartenders and I was passed up for the person next to me. Didn't matter if they just walked up. After about 10-15 minutes of waiting I gave up and had my friend try to order. He got our drinks in about 5 minutes. I'm not sure what it is about me, but I don't know why I would go back to a bar where I can't get served."},
#   {'date': '9/6/2015',
#    'rating': 4.0,
#    'content': "Cool outdoor seating area and decent selection of cocktails and beer, not too expensive. Don't recommend the Shangri-Lada though...tasted a bit like sizzurp."},
#   {'date': '7/18/2015',
#    'rating': 5.0,
#    'content': "Finally found my perfect divey bar in Austin. Great people, tunes and beverages. Indoor / outdoor area is very relaxed and prepared with seating and fans for hot nights. Pool tables, even a photo booth if you're feelin' fancy! Cheers."},
#   {'date': '7/11/2015',
#    'rating': 1.0,
#    'content': 'Bartender experience "HORRIBLE" DO NOT order ANY drinks from the female bartender that has the short black hair cut with the tattoos and I\'m hating my life look. I have never experienced such a rude individual with how she handled such a simple transaction and made it one of the worst night life experiences here in Austin. This bartender made a drink with dark liquor instead of clear, when I requested clear, I took one sip and it was awful \xa0imagine ice water with spiced rum \xa0:( I ended up getting a beer, but this morning I see that the drink was still charged on my friends card. \xa0 FIRST AND LAST EXPERIENCE with this bar!!!! watch out for the angry bartender who is hating her job and shouldn\'t work with customers if she cant do her job properly. Looking forward to telling everyone about my experience! \xa0Oh and lets not forget the name of the drink Sailor Jerry....'},
#   {'date': '7/5/2015',
#    'rating': 2.0,
#    'content': "To preface this review, I used to kind of enjoy this place. I'm just choosing to not go back after my most recent experience.I walked up to the bar and handed the bartender my card to start a tab. The bartender told my girlfriend and I that they'd hold the card for open tabs, we agreed and got our drinks. About 30 minutes later, I walked up to get some more drinks. I told the bartender my last name, and half started to walk away. The bartender that had served us was not there any longer, and the 2 remaining bartenders said they didn't have my card or a tab with my name on it.They looked through all of the kept cards at the bar, and checked the computer for any charges under my name. After a couple minutes of looking, the bartender suggested that I was in the wrong bar...and I had used my card at a neighboring bar for drinks. At this point I'm a little bit irritated, but not a big deal...surely someone knows what's going on. They sent me to the outside bar, the outside bartender (who was not the man who took my card originally) said it was silly of them to send me out there.I went back to the inside bar to speak with the people there again. After pulling up my bank statement and proving that there was a charge on my card, the bartender explained how charges generally don't show up that quickly. That's fine and I'd believe that...IF I WEREN'T LOOKING AT MY BANK STATEMENT. I asked my girlfriend to collaborate my story at this point, because it seemed like the staff didn't believe me. After about 15 minutes of standing at the bar, the bartender slammed a card holder down with my card in it. He explained to me closed out tabs have their cards left in a holder.I calmly explained to the staff that I had agreed to keep the tab open, and did not walk my tab. The bartender ended up giving us a few drinks on the house for our trouble, that is the only thing saving this review from a 1 star rating.I will not go back here again, there are PLENTY of other bars on east 6th street.TL;DR - I went to get a 2nd round of drinks for friends on an open tab, spent 30 minutes trying to find my credit card that the staff had lost."},
#   {'date': '5/19/2015',
#    'rating': 5.0,
#    'content': "Shangri-La is a fantastic divey-ish bar on E. 6th, with a good selection of liquor from top to bottom shelf, beers of every caliber, and reasonable prices. The bartenders have always been attentive, and the door guys are friendly given all the shit they put up with. **Seriously, I have almost never been when there wasn't a shitfaced couple trying to slur their way in, yet the stoic stewards are never afraid to deny entry. Just keep your mouth shut and try to walk straight. The jukebox has a good selection of punk which makes me really happy, and they have pool tables that you can usually get on without much trouble.Pros: - Fantastic backyard, lots of picnic tables where you can easily make new friends- Cocktails are on point- Prices are what you'd expect them to be- Friendly staffCons: - Pool tables/cues are kind of shitty, but I'm also real snobby about pool tables.- Bathroom lines can get real backed up (this only impacts the people who don't want to, most understandably, use the porta-potties sp?). Hell yeah, Shangri-La."},
#   {'date': '4/30/2015',
#    'rating': 4.0,
#    'content': "Much like my last review of Side Bar here too I haven't been too in about two years. It was my birthday tonight so yea why not bar hop around on a Monday night Bubba! Yea this is sorta a hipster bar and it's funny to make fun of them but they're also much better to be around then what hangs around other bars. Everyone here is just here to enjoy cheap drinks with good friends so it's zen I guess. Bartenders are great, and knowledgeable. I once stole a stuffed monkey off the wall for someone I dated. The back area is huge and relaxing for those cold winter nights and even more amazing on those hot Texas summer nights. Oh and the door guys have always been pleasant here! I think they have trivia nights here too for you trivia freaks. Shang's is awesome!"},
#   {'date': '3/4/2015',
#    'rating': 5.0,
#    'content': "Did a whirlwind tour of Austin (East Austin, SoCo, Rainey, 6th Street)...and this tops my list for fave dive bar. Cheap drinks and winter drink specials (warmed me up after an unseasonably-cold winter walk). Thumbs up for the bartender who gave me one on the \xa0house because they were changing out the special - \xa0I am not accustomed to that where I'm from!"},
#   {'date': '3/2/2015',
#    'rating': 3.0,
#    'content': "This was the 2nd stop for drinks on East 6th St on 2/6/15. I liked that the drinks were cheap. They weren't super busy so we were able to sit right at the bar and were served right away. The inside was divey, but the bartenders were friendly. There was a jukebox, but it didn't have anything that interested me or my friends. Only had one drink here before moving on to the next stop."},
#   {'date': '1/27/2015',
#    'rating': 4.0,
#    'content': 'Dimly lit artsy dive bar with no offensive odor and a pretty cool back patio. They have a pool table, some video games a photo booth and a jukebox with some jams. I appreciate being able to talk beer with the bartenders and not be rushed or shooed away. as far as beer goes they had some pretty good options available. This place works great for large groups but there are also smaller intimate seating/tables available. heads up on the patio! mind the steps and also for colder/warmer weather you just have to decide if you can tough it out or not. either way its a pretty good spot to check out.'},
#   {'date': '1/17/2015',
#    'rating': 4.0,
#    'content': "Shangri-La has cleaned up its backyard over the past few years, unfortunately this included the loss of an East Side King food truck. The interior is still pretty divey and the bathrooms are certainly included in that descriptor. The last time I went there wasn't even a functioning men's bathroom. I'm pretty sure there's also only a single woman's bathroom if you exclude the (likely disgusting) portapotties out back.The bar is cheap even for downtown Austin and the bartenders are friendly. Facial hair seems to be a prerequisite for employment, which makes total sense given its location. Music selection varies across a wide range from hip-hop to metal, so don't be surprised if you encounter music you might not enjoy."},
#   {'date': '9/25/2014',
#    'rating': 4.0,
#    'content': "Honestly I don't have much to say about this little bar, aside from the fact that it's a cute place to have a couple of drinks. The bartenders are generally swift, if sometimes a little short. They're fairly priced and in a great location, so it's a nice stop if you're out on the town for the night. I dig the decor and atmosphere; it's not pretentiously hip, but it's definitely cultivating an image. The bathroom sitch is a REAL issue, especially during peak hours (there is only one, and to alleviate the problem they're installed porta-potties in the back -- gross). Generally I'd say start here and leave by the time you need to go to the bathroom. Overall a decent time, 3.5-4 star experience."},
#   {'date': '9/16/2014',
#    'rating': 5.0,
#    'content': 'Ive been coming to this bar since it opened its doors. Have seen the crowds change and not mention the East side but this place holds strong even thru all the changes. Cool huge patio, when tress arent over grown you have a cool view of downtown. Small food trailer for late night snacking, nothing special food wise but still hits the spot when it up and running. Love the staff here they have sassy/friendly attitude which is what I think every bar needs. If you cant take a little sarcasm and some sassy-ness with your lone star and jamey then move on. No fake BS here! I work every year for SXSW and this place is always on my radar for a break and a quick beer. Much props to my man Miguel, always on point and knows how to handle 9 deep in any bar! All in all I will always continue to come to this place and have told many many peeps to stop in and say whats up, even for a quick beer. Thanks you guys and gals!!'},
#   {'date': '9/9/2014',
#    'rating': 5.0,
#    'content': "Absolute favorite bar in Austin, well it's actually tied with Midway Field House. But it's mainly because the bartenders. When it's slow, they make a point to have conversation with you, they don't just stand there and fuck off on their phone. There's awesome seating outside. Reminds me of home a little with the trees present. They have pool tables inside if that's your forte. CHEAPEST beers on east side, easily. I love this place and will continue to stop by. Great bar tenders, sweet patio, and cheap beers... What else can you ask for?One more thing: THEY HAVE PAUL'S BOUTIQUE ON THE JUKEBOX. Beastie Boys to seal the deal. Can I get a f*ck yeah?"},
#   {'date': '8/3/2014',
#    'rating': 5.0,
#    'content': 'Shang is exquisite, but instead of saying nice stuff I\'m going to pick a couple of nits, because this is Yelp:1. There\'s marklemorp on the jukebox, for some reason.2. On weekends the east side becomes a sort of field trip to the hipster zoo for all the horrible people you imagine when you think "fucking Californians ruining Austin". Shang is the first spot on the tour for these people. At the end of the night they go home and write about the cockroach they saw that ruined their weekend.'},
#   {'date': '8/2/2014',
#    'rating': 5.0,
#    'content': 'This place is great. My husband and I went with a group of friends and I ended up running into people there too. The drinks were good and the outside table sitting makes you make friends with random strangers. Awesome energy and its a great location. We easily were in walking distance of other bars and food trucks. Parking is either on the street or you have to find a random lot. Over all we stayed for four hours and had a blast with all the new people we met.'},
#   {'date': '8/2/2014',
#    'rating': 1.0,
#    'content': "Stupidest bar ever. I came here with 8 people. We stayed for 1 drink. We would have stayed for the entire night if the wait staff \xa0wasn't so fussy and rude. \xa0Bad service!"},
#   {'date': '7/12/2014',
#    'rating': 2.0,
#    'content': 'Went here on a saturday night for a friends going away party. okay place with a good backyard patio.Would\'ve been a great time except for when a friend got up on a chair for a going away toast, an employee was rude and said " get off the f&^%$inf=g chair" then told him he had to leave. He shouts "you don\'t work here, i work here and your\'e leaving" then he went out front to smoke a cigarette. Really rude, and this guy is lucky our 20 person party went elsewhere quietly, the guy he insulted is a jiujitsu blackbelt. MGMT: fire the overweight bar-back with the attitude problemr. hes spending his hours here insulting patrons and smoking.'},
#   {'date': '7/10/2014',
#    'rating': 2.0,
#    'content': "I guess it just didn't have much of a draw for me... I mean, I'd probably actually give it 2.5 stars, because its okay, and has a back 'patio' area, but most of East Austin has back patio areas (which are more like former dirt parking lots), so that's not too much of a determining factor for me. \xa0Basically, If you are really into bare bones dive bars, just looking to drink a Lone Star or something, and really like East Austin and happen to be in the area, then you will probably like it; but you will also find dozens of similar places in a few blocks surrounding it. \xa0But if you want to have drinks in a place with a much nicer ambiance, and have a mixologist make you a strong/unique cocktail or two (or still opt for a beer), try Whistlers or Eastside Showroom a few minute walk away."},
#   {'date': '6/16/2014',
#    'rating': 5.0,
#    'content': "I love coming here with my girl. It's a great atmosphere, awesome drinks and quite the atmosphere! Definitely one of my favorites off east sixth. I would definitely recommend a few drinks on the back porch relaxing during Texas summer nights!"},
#   {'date': '5/27/2014',
#    'rating': 2.0,
#    'content': "This was the only fail of my trip. We had checked out the website and saw a menu for burgers, burgers that are all named after pulp fiction characters. We are movie nerds so this made the list of places to check out. We went in and we're told there is no kitchen. Apparently there was a food truck in the back, but that is not a thing anymore. Please, fix your website. \xa0Since we were there we grabbed a beer, sat at a table and watched a huge cockroach run laps on the floor next to our table. Gross. I did give it two stars because it did have pool tables and for drinks and pool this wouldn't be a bad place for that."},
#   {'date': '5/20/2014',
#    'rating': 5.0,
#    'content': 'Home of the original Eastside hipsters, hipster haters and wanna bees.. everyone is welcome. \xa0It has that dive bar charm/ smell that makes me feel at home, and when you need some fresh air, they have one of the best outside patios on the eastside. \xa0I have know that bartenders for years and they are all bad asses. \xa0I really appreciate the way they always say hello and recognize that i am sort of a regular without being rude to the other customers.'},
#   {'date': '11/27/2013',
#    'rating': 4.0,
#    'content': 'Great Eastside Bar with a wonderful huge area outside in back. \xa0Get there early on the weekend if you want a big table with friends. \xa0Bar staff is friendly and cool. \xa0Good selection of drafts and full bar. \xa0They do get packed, but really one of the chillest spots to drink with friends in town.'},
#   {'date': '11/16/2013',
#    'rating': 3.0,
#    'content': "I want to like this place more than I do, really. The back patio is cool as reported, and they have a freakin' vintage Galaga/Ms. Pac-Man, fer' cryin' out loud. But one of the pool tables was broken, the prices are just okay, and their food stand offers the options of hamburgers or hamburgers. The tiny restrooms always have a line once the place gets busy, and the bar service, while quickish, wasn't especially friendly. I'd go again, but the Liberty has a better food truck and just as cool of an outdoor space."},
#   {'date': '11/4/2013',
#    'rating': 5.0,
#    'content': 'Up the stairs to a tree-shaded outdoor nirvana, down the stairs to a hopping joint, good times and lone stars either way! Great east side hangout bar.'},
#   {'date': '11/1/2013',
#    'rating': 4.0,
#    'content': 'If I had to pick a "coolest thing" about Shangri-La it would be their patio. Why wait downstairs with the proles when you can chill on the spacious and capacious upstairs patio tables with your friends and deputize the soberest of them to chivvy more beers up to you?Sadly East Side King isn\'t the upstairs trailer anymore (as of fall 2013 it\'s "Royale with Cheese" - get it?), so the appeal of being in the top tier has been diminished somewhat. However, you can still enjoy $2 Lone Stars, ~$4 pints of other beers, and variously priced shots in the downstairs lounge if you feel like slumming. I\'ve spent plenty of happy times either playing pool on their tables, just hanging around drinking, or cheering on friends as they hit on girls at the bar, since this place attracts a fairly cool spectrum of Austin personhood.Their Tuesday trivia is good, and their drinks are alright, so as an official East Sixth Bar you\'re practically mandated to at least check them out instead of visiting the teeming horror of flesh that is Dirty 6th these days.'},
#   {'date': '9/19/2013',
#    'rating': 4.0,
#    'content': 'When I first walked into Shanrgi La, first impressions were that it was tiny and dark. \xa0So when I stepped out into their open spaced backyard it was a bit of a surprise. This is where the action happens. It\'s beautiful outside, tables, long picnic benches and fairy lights strung through the giant trees.The bartender was great, I wish I could remember his name. I asked him to make my friend a birthday shot, whatever he thought she should have. He happily did it for us. I stayed until it was dark, so I could feel the full effect of the twinkling lights and of course the cider and one or two shots I had. When closing out my tab I gave the bartender the wrong name forgetting it was under my husband\'s name. But there was another Anastasia in the bar and so he wrung it up on the wrong card. When I realized in my half drunk state that "woah that is not my card." He fixed it quickly and waved off my apologies. He made fun of me a little which was totally called for and we laughed it off. I really wanted to yell out and find the other Anastasia because I don\'t meet very many of them. My wonderful friend did it for me, and no one turned around. \xa0It\'s possible, they were scared of the drunken people yelling their names and chose to ignore us. I will absolutely be back and drag all my friends with me too. And Other Anastasia if you are there and I yell for you turn around and say hi.'},
#   {'date': '9/19/2013',
#    'rating': 5.0,
#    'content': 'The divey-ist of dives (this is a good thing) and a top notch juke box. Oh and they have a pool table. Need I say more?'},
#   {'date': '9/6/2013',
#    'rating': 5.0,
#    'content': 'Favorite bar on the East Side, hands down. This place has a sweet vibe and awesome music and cheap drinks.'},
#   {'date': '8/9/2013',
#    'rating': 3.0,
# ...
#    'rating': 5.0,
#    'content': "shangri-la rules - it's cool without being obnoxious, drinks are cheap, staff is friendly, it's HUGE, the second sunday sock hop is there now, and it's on the east side, away from the horrors of 6th street."},
#   {'date': '1/10/2009',
#    'rating': 4.0,
#    'content': "This place is right around the corner from my studio, so for location points it scores high. Generally speaking though, when I'm hanging out east side I prefer to be able to chat with my friends. The last couple of times I've gone here it wasn't super conducive to a good conversation. The music was just a tad loud. Maybe I'm getting too old...But the crowd is cool, and the drinks seem reasonably priced. I've gone a few times, including once when they were holding a photo slide show event that was pretty cool. There's a lot of space, so it is definitely cool for the occasional event."},
#   {'date': '1/7/2009\n            \n\n\n\n\n\nUpdated review',
#    'rating': 4.0,
#    'content': "Amber: Let's go to Shangri-La!Friend: Yeah, I love that place.Amber: I love that place too, plus it's suuuper cheap! \xa0Friend: Yeah, that place is awesome.Amber: New Year's Eve was such a blast here.Door Guy: ID's, please?Amber: Here you go!Door Guy: Thanks![Door Guy begins sternly and vigorously molesting my purse]Amber: What are you doing?Door Guy: Checking for bottles....it suddenly feels a bit more divey to me."},
#   {'date': '1/1/2009',
#    'rating': 4.0,
#    'content': 'When you go look Wikipedia of the Ancients, seeker, you find answer."Shangri-La has become synonymous with any earthly paradise but particularly a mythical Himalayan utopia--a permanently happy land, isolated from the outside world. In the novel Lost Horizon, the people who live at Shangri-La are almost immortal, living years beyond the normal lifespan. The word also evokes the imagery of exoticism of the Orient. The story of Shangri-La is based on the concept of Shambhala, a mystical city in the Tibetan Buddhist tradition.In China, Tao Qian of the Jin Dynasty described a Shangri-La in his work Story of the Peach Blossom Valley (Chinese: pinyin: Táohu Yuán Jì). In modern China, the Zhongdian country was renamed to \xa0(Xinggéll, Shanri-La in Chinese) in 2001, to attract tourists. The legendary Kun Lun Mountains in Tibet offer other possible Shangri-La valleys.A popularly believed inspiration for Shangri-La is the Hunza Valley in northern Pakistan, close to the Tibetan border, which Hilton visited a few years before Lost Horizon was published. Being an isolated green valley surrounded by mountains, enclosed on the western end of the Himalayas, it closely matches the description in the novel. A Shangri-La resort in the nearby Skardu valley is a popular tourist attraction.Today, various places claim the title, such as parts of southern Kham in southwestern Yunnan province, including the tourist destinations of Lijiang and Zhongdian. Places like Sichuan and Tibet also claim the real Shangri-La was in its territory. In 2001, Tibet Autonomous Region put forward a proposal that the three regions optimise all Shangri-la tourism resources and promote them as one. After failed attempts to establish a China Shangri-la Ecological Tourism Zone in 2002 and 2003, government representatives of Sichuan and Yunnan provinces and Tibet Autonomous Region signed a declaration of cooperation in 2004. Also in 2001, Zhongdian County in northwestern Yunnan officially renamed itself Shangri-La County.Shangri-la is often used in a similar context to which "Garden of Eden" might be used, to represent a perfect paradise that exists hidden from modern man. It can sometimes be used as an analogy for a life-long quest or something elusive that is much sought. For a man who spends his life obsessively looking for a cure to a disease, such a cure could be said to be that man\'s "Shangri-La". It also might be used to represent perfection that is sought by man in the form of love, happiness, or Utopian ideals. It may be used in this context alongside other mythical and famous examples of somewhat similar metaphors such as The Holy Grail, El Dorado, The Fountain of Youth, and to an extent "white whale" (referring to the white whale chased by the obsessed Captain Ahab in the book Moby-Dick)."Yeah. Shangri-La is a bar, dude, on the east side. It is quite cool - they have a huge outdoor patio thing, the entryway of which is lined with something those of us who have been are pretty sure is glittering mashed glass gravel. On the inside, they\'ve got about 6 or 7 arcade machines right smack from the early 80\'s, all neary functional, still only a quarter [BLUE VALKYRIE IS ABOUT TO DIE!] 2 pool tables and many cues (hey, we all know the usual cue at a bar is gonna suck, but at least you can pick the least shitty one instead of one that is for somebody 3 feet tall).They have a functional jukebox with a bevy of soundtrax and the 3 tunes for a buck. I was there NYE, the drinks were strong, and they had the \'2nd Sunday Sock Hop\' going on with all night DJ, a $10 cover & free entry before 9.At least one ambulance showed up for a passed out girl, and as I\'ve mentioned before, though I don\'t agree, Ice-T & Body Count once told me that unless 2 ambulances show up during a show, it\'s no good. Although Shangri-La mentioned \'bar food\' for $1, which is nice of them (and we\'re still uncertain what the \'bar food\' was) really the only thing keeping this place f ...
#   {'date': '1/1/2009',
#    'rating': 4.0,
#    'content': '"Alright, who\'s gonna be Merlin?""Aw, just one more quarter...C\'MONNNN!" and"How the hell did you just make that side pocket shot!?"These are samples of the kind of time I\'ve had playing quarter-run games in Shangri-La of the East on my last visit there for New Year\'s. *Bows* Commendable attributes I\'ve noticed on other occasions:*Gongg*$4.75 pints of Bloody Mary and ATTENTIVE bartenders inside! I think we could have winked at the coasters and our Neil Patrick Harris look-alike server would have been recommending another concoction to give a go. If my group were instead chatting about more universal subjects I\'m positive he would have joined in. A real cool cat, that one was.Two pool tables in the back (bring out yer quarters) plus a few old school game consoles in back of the back. Although, only 4 out of 7 of these work, including Tetris and a Gauntlet console whose Thyra didn\'t work and the Wizard firing button was jammed. Bummer!There\'s a good number of smaller, more intimate tables nearer to the jukebox. On a regular night the music isn\'t so loud that two people can\'t converse unless they\'re in each others\' ear, but three people may have trouble hearing unless they sit close. Tell them to come hither, then.The upper patio level has a satellite bar that serves a good handful of beer on tap, but tabs at each bar remain separate. PLENTY more room on this patio. I\'m talking mid-sized-dance-floor worthy. And did we *ever* see that worth during their first Sock Hop last night for New Year\'s Eve. I\'m talking Grease-inspired, swing-skirt-but-also-Truman-Capote-encouraged attire with many shaking their tail feathers in Pumas for the very purpose to more easily scoot shuffle n\' swing.Shangri-La: the paradise where East meets West. Golly, you better believe it, Mister.*Gongg*'},
#   {'date': '12/29/2008',
#    'rating': 4.0,
#    'content': 'Very cute. \xa0Was only the there for a moment, but will go back... I will take this moment to plug Pete\'s bar, which is directly in front of Shangri-La. \xa0Pete and "Mama" run this tiny little bar. \xa0If you\'re not afraid to go into the real "local" bars, this place can be a lot of fun. \xa0Really laid back and cool. \xa0Hubby and I got drunk and karaoked all night. \xa0Take a visit, spread your money around... they\'ll remember your name. \xa0If you\'re feeling REALLY adventurous, check out the White Swan, which is next to Sam\'s BBQ. \xa0The bar owner there is named Jazzy Jeff... but please... no DJ Jazzy Jeff jokes... hubby made that mistake... it was awkward...'},
#   {'date': '12/27/2008',
#    'rating': 5.0,
#    'content': "You had me at Asteroids, then you buttered me up with rum and coke. \xa0Shangri-La, you're my kind of dive."},
#   {'date': '12/19/2008\n            \n\n\n\n\n\nUpdated review',
#    'rating': 5.0,
#    'content': "What is paradise?What makes a good bar?Cheap beer. Pool tables. A wall of old arcade games. Friendly staff. Great jukebox. Girl in Olivia Newton-John pants. Running into old friends. Feeling like you're in someone really cool's den, and that you can come back any time you want. Walking distance from my house.Girl in Olivia Newton-John pants (!).Paradise. Good bar. Shangri-La."},
#   {'date': '12/19/2008',
#    'rating': 4.0,
#    'content': 'I would like to open this review with a rendition of Jem and the Holograms\' hit song of the same name:Shangri-La, Shangri-LaWhere are you hiding?Shangri-La, Shangri-LaWhere can you be?If I keep searching, I will find youShangri-La, show yourself to meAre you just a fantasy?So it would seemBut somethin\' in my heart saysYou are more than just a dreamShangri-La, Shangri-La, I\'m pressing onwardShangri-La, Shangri-La, I\'m on my wayWon\'t give up hoping, nothing will stop meShangri-La, I will find you somedayShangri-La, Shangri-La, Shangri-LaI will find you somedayShangri-La, Shangri-LaFor some reason that seemed appropriate.At first glance the hipster vibe of this place turned me off since I\'m not a fan of jeans you have to be sewn into, glasses rims circa 1987 or ironically drinking PBR, but that might just be me. There was an intriguing assortment of gun paintings on plywood hanging on the wall, which may have held my attention just long enough to allow the vibe to be redeemed by the plethora of old-school arcade style video games in the back corner. If there\'s one thing I love, it\'s a little Mortal Kombat with my cocktails. They also get points for super-sweet bartenders, a special "Shangri-La Blend" hand soap in the ladies room, and for playing the music loud enough to hear, but not so loud that I couldn\'t carry on complete conversations with the people I was there with.Oh, and they played Tupac - whether intended as ironic or just damn good music that earns some points in my book.'},
#   {'date': '12/18/2008',
#    'rating': 5.0,
#    'content': 'From the moment you accidentally walk into the Tejano bar right next to it, to the time you leave Shangri-La a good time is waiting to be had. \xa0Everything this place is great. \xa0The outdoor "anteroom" covered by a corrugated tin roof held up by wooden posts, like something you\'d find in a backyard. \xa0The half stairway that leads from the ID checkpoint to the lounge. \xa0The teal/sea-green colored walls of the lounge, and the chandelier hanging above the bar. \xa0In the lounge they have old school arcade games like Mortal Kombat II and Centipede, and others. \xa0In the same area there\'s two pool tables. \xa0The jukebox has some cool vintage selections like Booker T & The MG\'s - Green Onions. \xa0The bathroom has a lock on it, in case you need to do something, that I would only wish upon my worse enemy, while at a dive/downtown bar...and as a nice bonus appeared quite clean! \xa0The chairs and sofas looked like something out of a 50\'s malt shop or stag movie lounge. \xa0All this and we still haven\'t gone outside. \xa0From the entrance a small stone 1/4 stairway leads to the beer garden which is spacious, has a big old tree, and a great view of the rooftop.It may be tricky to find for first timers, so remember that the entrance is in the rear.'},
#   {'date': '12/16/2008',
#    'rating': 5.0,
#    'content': "As a resident of the East side, I have been anxiously awaiting another place to go on this side of 35. \xa0And this is the place! \xa0The juke box is one of the best I've heard in Austin (sure I've only been here a year but still), there are video games - PacMan and Mortal Kombat 2 to name a few. There are pool tables, not just one. \xa0The bartenders are all super cool and nice.The pool cue nautical star clock on the wall is a nice touch. \xa0And the beer garden is amazing. I forsee many a Spring evening out back in my future."},
#   {'date': '12/10/2008',
#    'rating': 5.0,
#    'content': 'Oh this place is so fun! \xa0Juke box, video games, awesome outside space. Okay, I\'m not saying anything new. \xa0But definitely worth checking out if you\'re into the Rio Rita vibe. \xa0A long time Austin service industry friend has informed me that after just 3 weeks of being open it\'s already "ruined" by the "hipsters" so take half a point off, but i\'m not an in-the-know industry person so i don\'t really care about that. Plus I accidently went to a photo art event at Shangri-La one friday and there were LOTS of cute boys, so, you know, half a star up again!Warning: be careful on the rail-less stairs!'},
#   {'date': '12/9/2008',
#    'rating': 5.0,
#    'content': "The latest beerland incarnation on E 6th. \xa0 The outside is lovely. \xa0I really can't wait for summer to hang out back there. \xa0The juke box is also pretty worthy. \xa0There are a few random curve balls in there, like disbanded Austin bands from several years ago. \xa0The drink prices are also reasonable."},
#   {'date': '12/1/2008',
#    'rating': 5.0,
#    'content': 'Formerly "Club Impact" (for what, about a week?), I\'m glad Shangri-la didn\'t turn into another sketchy east side sports bar. I walk by this place every morning on my way to work, so I was intrigued to see the teal paint go up. Honestly, I wouldn\'t shut up about it for the couple of weeks before it opened, and I was there within the first three days.Its expansive interior was thankfully uncrowded, although we got there early. Two bar-sized pool tables and what may be best-described as \'nouveau retro\' interior makes you feel kind of like you\'re hanging out in your grandparents\' basement, if your grandparents are the type to have a great jukebox and pictures of guns on the wall (it\'s classier than it sounds). Beer prices are comparable to anywhere else in this neighborhood, which is to say, perfectly reasonable.The biggest selling point, most likely, is the enormous back yard - not terribly amenable to winter weather, but bigger than Rio Rita\'s (by far) and replete with picnic tables. Plus there were guys out there telling me they\'d watch my bike for me because the bike racks hadn\'t arrived yet. Back in Brooklyn I would have walked out at that, but these guys actually meant it.In a nutshell: If you must walk west down 6th St., this is as far as you need go. No kids and no white hats, just plenty of room and a relaxing atmosphere.'},
#   {'date': '12/1/2008',
#    'rating': 4.0,
#    'content': "Shangri-La is great if you actually want to have a conversation with your drinks. They have multiple seating areas, outside and inside. The patio will be great in the spring. They have cheap well drinks ($2.75), a good selection of bottled beers (don't remember what was on tap), and little bottles of champagne. The bathroom doors have funny paintings to let you know which is which. If you miss the old club deville set up, you'll like the Shangri-La."},
#   {'date': '11/24/2008',
#    'rating': 5.0,
#    'content': "Since it's opening last weekend, I've been to Shangri-la twice... \xa0it's so nice to find a bar to go to, where the people are cool and chill... and you don't have to worry about the over-crowding and traffic that's on the other side of 35... The entrance is on the side street Medina.. and it opens to a huge out door patio that is two levels... there is an outdoor bar.... and there is enough outdoor seating for several large groups to sit outside, chat, drink and smoke cigs.It's got a great atmosphere... it's chill....inside they've got pool tables... great music on the jukebox, and both times they've been playing cool movies...The owners are awesome! It's definitely my new favorite bar in Austin..."}]}

# %%
r1.lower()
# Out:
# "we have been to shangri-la a couple of times now, and i can't really pinpoint what i like about this place, but i know i like to go there and meet with friends to sit in the backyard.the prices are fair, the people are great and there's a pool.although there's five similar bars to this in the 500 feet radius, this is definitely a great one.definitely try the miami vice frozen drink on a hot (summer)day.i would say come for the live music, but that is one of the only things i have never seen here"

# %%
#first page for business info

url = 'https://www.yelp.com/biz/shangri-la-austin-2?start=0&sort_by=date_desc'
response = requests.get(url, headers=headers, verify=False).text
page = BeautifulSoup(response, "lxml")
# Out:
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
hours = page.find('table',attrs={'class':'table table-simple hours-table'}).find_all('tr')
info = page.find('div',attrs={'class':'short-def-list'})

# %%
info_raw = page.find('div',attrs={'class':'short-def-list'})
info = dict(zip([x.text.strip() for x in info.find_all('dt')], [x.text.strip() for x in info.find_all('dd')]))
# Out:
# {'Takes Reservations': 'No',
#  'Accepts Credit Cards': 'Yes',
#  'Accepts Apple Pay': 'No',
#  'Parking': 'Street',
#  'Bike Parking': 'Yes',
#  'Good for Groups': 'Yes',
#  'Ambience': 'Divey, Hipster',
#  'Noise Level': 'Loud',
#  'Music': 'Live, Juke Box',
#  'Alcohol': 'Full Bar',
#  'Good For Happy Hour': 'Yes',
#  'Best Nights': 'Thu, Fri, Sat',
#  'Smoking': 'Outdoor Area / Patio Only',
#  'Outdoor Seating': 'Yes',
#  'Wi-Fi': 'No',
#  'Has TV': 'Yes',
#  'Dogs Allowed': 'Yes',
#  'Has Pool Table': 'Yes'}

# %%
[x.text.strip() for x in info.find_all('dd')]
# Out:
# ['No',
#  'Yes',
#  'No',
#  'Street',
#  'Yes',
#  'Yes',
#  'Divey, Hipster',
#  'Loud',
#  'Live, Juke Box',
#  'Full Bar',
#  'Yes',
#  'Thu, Fri, Sat',
#  'Outdoor Area / Patio Only',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes']

# %%
[dict([x.text.strip().split('\n\n')[0:2]]) for x in page.find('table',attrs={'class':'table table-simple hours-table'}).find_all('tr')]
# Out:
# [{'Mon': '4:00 pm - 2:00 am'},
#  {'Tue': '4:00 pm - 2:00 am'},
#  {'Wed': '4:00 pm - 2:00 am'},
#  {'Thu': '4:00 pm - 2:00 am'},
#  {'Fri': '2:00 pm - 2:00 am'},
#  {'Sat': '2:00 pm - 2:00 am'},
#  {'Sun': '2:00 pm - 2:00 am'}]

# %%
for x in hours:
    print(x)
    print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
# Out:
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# <h3>
#             Hours
#         </h3>
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# <table class="table table-simple hours-table">
# <tbody>
# <tr>
# <th scope="row">Mon</th>
# <td>
# <span class="nowrap">4:00 pm</span> - <span class="nowrap">2:00 am</span>
# </td>
# <td class="extra">
# </td>
# </tr>
# <tr>
# <th scope="row">Tue</th>
# <td>
# <span class="nowrap">4:00 pm</span> - <span class="nowrap">2:00 am</span>
# </td>
# <td class="extra">
# </td>
# </tr>
# <tr>
# <th scope="row">Wed</th>
# <td>
# <span class="nowrap">4:00 pm</span> - <span class="nowrap">2:00 am</span>
# </td>
# <td class="extra">
# <span class="nowrap open">Open now</span>
# </td>
# </tr>
# <tr>
# <th scope="row">Thu</th>
# <td>
# <span class="nowrap">4:00 pm</span> - <span class="nowrap">2:00 am</span>
# </td>
# <td class="extra">
# </td>
# </tr>
# <tr>
# <th scope="row">Fri</th>
# <td>
# <span class="nowrap">2:00 pm</span> - <span class="nowrap">2:00 am</span>
# </td>
# <td class="extra">
# </td>
# </tr>
# <tr>
# <th scope="row">Sat</th>
# <td>
# <span class="nowrap">2:00 pm</span> - <span class="nowrap">2:00 am</span>
# </td>
# <td class="extra">
# </td>
# </tr>
# <tr>
# <th scope="row">Sun</th>
# <td>
# <span class="nowrap">2:00 pm</span> - <span class="nowrap">2:00 am</span>
# </td>
# <td class="extra">
# </td>
# </tr>
# </tbody>
# </table>
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# <a href="/biz_attribute?biz_id=9zTOwKZ8JEC9snIIks1ejw">
# <span aria-hidden="true" class="icon icon--14-pencil icon--size-14 icon--currentColor link-more edit-info u-space-r1" style="width: 14px; height: 14px;">
# <svg class="icon_svg" role="img">
# <use xlink:href="#14x14_pencil"></use>
# </svg>
# </span>Edit business info
#     </a>
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
p = page.find_all("div", attrs={'class': 'review-content'})[0]

# %%
date = p.find('span', attrs={'class': 'rating-qualifier'}).text.strip()
rating = float(p.find('img').attrs['alt'][:3])
content = p.find('p', attrs={'lang': 'en'}).text

# %%
content
# Out:
# "We have been to Shangri-la a couple of times now, and I can't really pinpoint what I like about this place, but I know I like to go there and meet with friends to sit in the backyard.The prices are fair, the people are great and there's a pool.Although there's five similar bars to this in the 500 feet radius, this is definitely a great one.Definitely try the Miami Vice frozen drink on a hot (Summer)day.I would say come for the live music, but that is one of the only things I have never seen here"

# %%
for x in date.stripped_strings: print(x)
# Out:
# 7/30/2019

# %%
# Out:
# [<generator object stripped_strings at 0x1a132226d0>]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-263b44827dc4> in <module>()
# ----> 1 date.select()
#
# TypeError: select() missing 1 required positional argument: 'selector'

# %%
p
# Out:
# <div class="review-content">
# <div class="biz-rating biz-rating-large biz-rating-large--wrap clearfix">
# <div class="biz-rating__stars">
# <div class="i-stars i-stars--regular-5 rating-large" title="5.0 star rating">
# <img alt="5.0 star rating" class="offscreen" height="303" src="https://s3-media2.fl.yelpcdn.com/assets/srv0/yelp_design_web/9bec2045845c/assets/img/stars/stars.png" width="84"/>
# </div>
# </div>
# <span class="rating-qualifier">
#         7/30/2019
#     </span>
# </div>
# <p lang="en">We have been to Shangri-la a couple of times now, and I can't really pinpoint what I like about this place, but I know I like to go there and meet with friends to sit in the backyard.<br/><br/>The prices are fair, the people are great and there's a pool.<br/>Although there's five similar bars to this in the 500 feet radius, this is definitely a great one.<br/><br/>Definitely try the Miami Vice frozen drink on a hot (Summer)day.<br/><br/>I would say come for the live music, but that is one of the only things I have never seen here</p>
# </div>
